# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash2000A/Enzydock/blob/main/Python_series2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# @title
# !pip install python-pptx matplotlib

# %%
from IPython.display import IFrame

# Embed the Google Slides presentation in a clean, editable mode
IFrame("https://docs.google.com/presentation/d/1v7y2Ar_oUmDeA2tHRCLR2Z3HZkCOLLSt/edit#slide=id.p0", width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://docs.google.com/presentation/d/1v7y2Ar_oUmDeA2tHRCLR2Z3HZkCOLLSt/edit#slide=id.p0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame

# Embed the Google Slides presentation in a clean, editable mode
IFrame("https://docs.google.com/presentation/d/1v7y2Ar_oUmDeA2tHRCLR2Z3HZkCOLLSt/edit#slide=id.p3", width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://docs.google.com/presentation/d/1v7y2Ar_oUmDeA2tHRCLR2Z3HZkCOLLSt/edit#slide=id.p3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
from IPython.display import IFrame

# Embed Google Slides in a clean, distraction-free mode, with the specific slide visible
IFrame("https://docs.google.com/presentation/d/1v7y2Ar_oUmDeA2tHRCLR2Z3HZkCOLLSt/embed?start=true&loop=true&delayms=5000#slide=id.p3", width="100%", height="800px")
# Out:
#         <iframe
#             width="100%"
#             height="800px"
#             src="https://docs.google.com/presentation/d/1v7y2Ar_oUmDeA2tHRCLR2Z3HZkCOLLSt/embed?start=true&loop=true&delayms=5000#slide=id.p3"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
